# %% [markdown]
# # Telecom X – Parte 2: Prevendo Churn

# %% [markdown]
# Este notebook é opcional. Você pode rodar o script `src/telecom_part2.py` pela linha de comando.

# %% [markdown]
# Para usar aqui, ajuste os caminhos e execute as células.

# %%
from pathlib import Path
from pprint import pprint
import json
import pandas as pd

# %%
DATA_PATHS = [Path('../data/telecom_tratado.csv'), Path('../data/dados_tratados.csv')]
for p in DATA_PATHS:
    if p.exists():
        df = pd.read_csv(p)
        print('Carregado:', p)
        display(df.head())
        break
else:
    print('Coloque o dataset tratado em ../data/')
# Out:
# Carregado: ..\data\telecom_tratado.csv
#    customerid customer.gender  customer.seniorcitizen customer.partner  \
# 0  0002-ORFBO          Female                       0              Yes
# 1  0003-MKNFE            Male                       0               No
# 2  0004-TLHLJ            Male                       0               No
# 3  0011-IGKFF            Male                       1              Yes
# 4  0013-EXCHZ          Female                       1              Yes
#
#   customer.dependents  customer.tenure account.contract account.paymentmethod  \
# 0                 Yes                9         One year          Mailed check
# 1                  No                9   Month-to-month          Mailed check
# 2                  No                4   Month-to-month      Electronic check
# 3                  No               13   Month-to-month      Electronic check
# 4                  No                3   Month-to-month          Mailed check
#
# ...

# %%
# Após treinar com o script, visualize as métricas
from pathlib import Path
import json
m = Path('../reports/metrics.json')
if m.exists():
    print('Métricas:')
    print(json.dumps(json.loads(m.read_text(encoding='utf-8')), indent=2, ensure_ascii=False))
else:
    print('Rode: python src/telecom_part2.py')
# Out:
# Rode: python src/telecom_part2.py
